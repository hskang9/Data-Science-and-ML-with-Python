# %% [markdown]
# # Train / Test

# %% [markdown]
# We'll start by creating some data set that we want to build a model for (in this case a polynomial regression):

# %%
# %matplotlib inline
import numpy as np
from pylab import *

np.random.seed(2)

pageSpeeds = np.random.normal(3.0, 1.0, 100)
purchaseAmount = np.random.normal(50.0, 30.0, 100) / pageSpeeds


scatter(pageSpeeds, purchaseAmount)

# %% [markdown]
# Now we'll split the data in two - 80% of it will be used for "training" our model, and the other 20% for testing it. This way we can avoid overfitting.

# %%
trainX = pageSpeeds[:80]
testX = pageSpeeds[80:]

trainY = purchaseAmount[:80]
testY = purchaseAmount[80:]

# %% [markdown]
# Here's our training dataset:

# %%
scatter(trainX, trainY)

# %% [markdown]
# And our test dataset:

# %%
scatter(testX, testY)

# %% [markdown]
# Now we'll try to fit an 8th-degree polynomial to this data (which is almost certainly overfitting, given what we know about how it was generated!)

# %%
x = np.array(trainX)
y = np.array(trainY)

p4 = np.poly1d(np.polyfit(x, y, 8))

# %% [markdown]
# Let's plot our polynomial against the training data:

# %%
import matplotlib.pyplot as plt

xp = np.linspace(0, 7, 100)
axes = plt.axes()
axes.set_xlim([0,7])
axes.set_ylim([0, 200])
plt.scatter(x, y)
plt.plot(xp, p4(xp), c='r')
plt.show()

# %% [markdown]
# And against our test data:

# %%
testx = np.array(testX)
testy = np.array(testY)

axes = plt.axes()
axes.set_xlim([0,7])
axes.set_ylim([0, 200])
plt.scatter(testx, testy)
plt.plot(xp, p4(xp), c='r')
plt.show()

# %% [markdown]
# Doesn't look that bad when you just eyeball it, but the r-squared score on the test data is kind of horrible! This tells us that our model isn't all that great...

# %%
from sklearn.metrics import r2_score

r2 = r2_score(testy, p4(testx))

print(r2)
# Out:
# 0.30018168612

# %% [markdown]
# ...even though it fits the training data better:

# %%
from sklearn.metrics import r2_score

r2 = r2_score(np.array(trainY), p4(np.array(trainX)))

print(r2)
# Out:
# 0.642706951469

# %% [markdown]
# If you're working with a Pandas DataFrame (using tabular, labeled data,) scikit-learn has built-in train_test_split functions to make this easy to do.
#
# Later we'll talk about even more robust forms of train/test, like K-fold cross-validation - where we try out multiple different splits of the data, to make sure we didn't just get lucky with where we split it.

# %% [markdown]
# ## Activity

# %% [markdown]
# Try measuring the error on the test data using different degree polynomial fits. What degree works best?

# %%
testx = np.array(testX)
testy = np.array(testY)

p5 = np.poly1d(np.polyfit(testX, testY, 5))

# %%
axes = plt.axes()
axes.set_xlim([0,7])
axes.set_ylim([0, 200])
plt.scatter(testx, testy)
plt.plot(xp, p5(xp), c='r')
plt.show()

# %%
from sklearn.metrics import r2_score

r2 = r2_score(testy, p5(testx))

print(r2)
# Out:
# 0.773601864416

# %%
p6 = np.poly1d(np.polyfit(testX, testY, 6))
axes = plt.axes()
axes.set_xlim([0,7])
axes.set_ylim([0, 200])
plt.scatter(testx, testy)
plt.plot(xp, p6(xp), c='r')
plt.show()
from sklearn.metrics import r2_score

r2 = r2_score(testy, p6(testx))

print(r2)
# Out:
# 0.826250281584

# %%
p7 = np.poly1d(np.polyfit(testX, testY, 7))
axes = plt.axes()
axes.set_xlim([0,7])
axes.set_ylim([0, 200])
plt.scatter(testx, testy)
plt.plot(xp, p7(xp), c='r')
plt.show()
from sklearn.metrics import r2_score

r2 = r2_score(testy, p7(testx))

print(r2)
# Out:
# 0.843014187023

# %%
p8 = np.poly1d(np.polyfit(testX, testY, 8))
axes = plt.axes()
axes.set_xlim([0,7])
axes.set_ylim([0, 200])
plt.scatter(testx, testy)
plt.plot(xp, p8(xp), c='r')
plt.show()
from sklearn.metrics import r2_score

r2 = r2_score(testy, p8(testx))

print(r2)
# Out:
# 0.849923014124

# %%
p9 = np.poly1d(np.polyfit(testX, testY, 9))
axes = plt.axes()
axes.set_xlim([0,7])
axes.set_ylim([0, 200])
plt.scatter(testx, testy)
plt.plot(xp, p9(xp), c='r')
plt.show()
from sklearn.metrics import r2_score

r2 = r2_score(testy, p9(testx))

print(r2)
# Out:
# 0.851170062431

# %%
p11 = np.poly1d(np.polyfit(testX, testY, 11))
axes = plt.axes()
axes.set_xlim([0,7])
axes.set_ylim([0, 200])
plt.scatter(testx, testy)
plt.plot(xp, p11(xp), c='r')
plt.show()
from sklearn.metrics import r2_score

r2 = r2_score(testy, p11(testx))

print(r2)
# Out:
# 0.932683182997

# %% [markdown]
# the error on test data decreases as the degree increases, but degree of 5 gives best result of training without overfitting.
